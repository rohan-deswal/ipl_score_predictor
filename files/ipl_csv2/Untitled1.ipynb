# %%
import pandas as pd

# %%
data = pd.read_csv('.\981019.csv')
data.describe()
# Out:
#        match_id  season     innings        ball  runs_off_bat   extras  \
# count     250.0   250.0  250.000000  250.000000    250.000000  250.000
# mean   981019.0  2016.0    1.496000    9.824800      1.540000    0.092
# std         0.0     0.0    0.500987    5.845235      1.894931    0.415
# min    981019.0  2016.0    1.000000    0.100000      0.000000    0.000
# 25%    981019.0  2016.0    1.000000    4.600000      0.000000    0.000
# 50%    981019.0  2016.0    1.000000    9.600000      1.000000    0.000
# 75%    981019.0  2016.0    2.000000   15.100000      2.000000    0.000
# max    981019.0  2016.0    2.000000   19.600000      6.000000    5.000
#
#            wides  noballs  byes  legbyes  penalty  other_wicket_type  \
# count  10.000000      0.0   1.0      7.0      0.0                0.0
# mean    1.500000      NaN   1.0      1.0      NaN                NaN
# std     1.269296      NaN   NaN      0.0      NaN                NaN
# ...

# %%
print(data['season', 'run'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('season', 'run')
#
# ...
