# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("files_relevant/all_matches.tsv", sep='\t')
df
# Out:
#       Unnamed: 0                                       venue  innings  ball  \
# 0              0                       M Chinnaswamy Stadium        1   5.6
# 1              1                       M Chinnaswamy Stadium        2   5.6
# 2              2  Punjab Cricket Association Stadium, Mohali        1   5.6
# 3              3  Punjab Cricket Association Stadium, Mohali        2   5.8
# 4              4                            Feroz Shah Kotla        1   5.6
# ...          ...                                         ...      ...   ...
# 1629        1629    MA Chidambaram Stadium, Chepauk, Chennai        2   5.7
# 1630        1630                    Wankhede Stadium, Mumbai        1   5.6
# 1631        1631                    Wankhede Stadium, Mumbai        2   5.6
# 1632        1632    MA Chidambaram Stadium, Chepauk, Chennai        1   5.6
# 1633        1633    MA Chidambaram Stadium, Chepauk, Chennai        2   5.6
#
#                      batting_team                 bowling_team  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore
# 1     Royal Challengers Bangalore        Kolkata Knight Riders
# 2             Chennai Super Kings              Kings XI Punjab
# 3                 Kings XI Punjab          Chennai Super Kings
# 4                Rajasthan Royals             Delhi Daredevils
# ...                           ...                          ...
# 1629  Royal Challengers Bangalore               Mumbai Indians
# 1630          Chennai Super Kings               Delhi Capitals
# 1631               Delhi Capitals          Chennai Super Kings
# 1632        Kolkata Knight Riders          Sunrisers Hyderabad
# 1633          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                                                 batsmen  \
# 0                     SC Ganguly,RT Ponting,BB McCullum
# 1     W Jaffer,R Dravid,CL White,MV Boucher,V Kohli,...
# 2                         MEK Hussey,PA Patel,ML Hayden
# 3                                       JR Hopes,K Goel
# 4                    T Kohli,YK Pathan,SR Watson,M Kaif
# ...                                                 ...
# 1629    V Kohli,RM Patidar,GJ Maxwell,Washington Sundar
# 1630            F du Plessis,SK Raina,RD Gaikwad,MM Ali
# 1631                                   PP Shaw,S Dhawan
# 1632                                N Rana,Shubman Gill
# 1633            DA Warner,JM Bairstow,WP Saha,MK Pandey
#
#                                                 bowlers  runs
# 0                              Z Khan,P Kumar,AA Noffke    61
# 1                          I Sharma,AB Dinda,AB Agarkar    26
# 2                            JR Hopes,S Sreesanth,B Lee    53
# 3                                      MS Gony,JDP Oram    63
# 4                       MF Maharoof,B Geeves,GD McGrath    40
# ...                                                 ...   ...
# 1629              JJ Bumrah,M Jansen,TA Boult,KH Pandya    46
# 1630            CR Woakes,Avesh Khan,TK Curran,R Ashwin    33
# 1631                      DL Chahar,SM Curran,SN Thakur    65
# 1632   Mohammad Nabi,B Kumar,Sandeep Sharma,T Natarajan    50
# 1633  Harbhajan Singh,Shakib Al Hasan,M Prasidh Kris...    35
#
# [1634 rows x 9 columns]

# %%
plt.rcParams['xtick.labelsize'] = 8

df_innings_1 = df.loc[df["innings"] == 1]
df_innings_2 = df.loc[df["innings"] == 2]

plt.figure(figsize=(15,10))

plt.subplot(211)
plt.xticks(rotation=90, ticks = [i for i in range(0, 110, 2)])
plt.title("1st Innings")
plt.hist(df_innings_1["runs"], bins = [x for x in range(110)], color='r', alpha = 0.5)

plt.subplot(212)
plt.xticks(rotation=90, ticks = [i for i in range(0, 110, 2)])
plt.title("2nd Innings")
plt.hist(df_innings_2["runs"], bins = [x for x in range(110)], color='b', alpha = 0.5)

plt.show()

# %%
df_innings_1.describe()
# Out:
#         Unnamed: 0  innings        ball        runs
# count   817.000000    817.0  817.000000  817.000000
# mean    816.000000      1.0    5.619217   45.007344
# std     471.983757      0.0    0.056969   11.368168
# min       0.000000      1.0    4.700000   15.000000
# 25%     408.000000      1.0    5.600000   37.000000
# 50%     816.000000      1.0    5.600000   45.000000
# 75%    1224.000000      1.0    5.600000   52.000000
# max    1632.000000      1.0    5.900000   84.000000

# %%
df_innings_2.describe()
# Out:
#         Unnamed: 0  innings        ball        runs
# count   817.000000    817.0  817.000000  817.000000
# mean    817.000000      2.0    5.605386   46.723378
# std     471.983757      0.0    0.198821   12.549094
# min       1.000000      2.0    1.100000    2.000000
# 25%     409.000000      2.0    5.600000   38.000000
# 50%     817.000000      2.0    5.600000   46.000000
# 75%    1225.000000      2.0    5.600000   55.000000
# max    1633.000000      2.0    5.900000  105.000000
